# %%
import os
import sys
module_path = os.path.abspath(os.path.join('../../..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import numpy as np
import tensorflow as tf

import ND_north_star.src.noise_generators.perlin_noise_generator as PNG # type: ignore
import ND_north_star.src.edge_detection.gradient_detection as ED_sim # type: ignore
from ND_north_star.src.utils.sampling_function import random_sampler # type: ignore
from ND_north_star.src.data_fillers.kNN_filler import kNN_data_filler # type: ignore

# %%
tf.config.list_physical_devices('GPU')
# Out:
# []

# %% [markdown]
# Disable GPU

# %%
tf.config.set_visible_devices([], 'GPU')

# %% [markdown]
# ## Generate dataset

# %%
resolution = 30
octaves = 4
dataset_size = 1024
drop_percs = [x/100 for x in range(0, 100, 5)]

# %%
data_path = "data/"
if not os.path.exists(data_path):
    os.makedirs(data_path)
data_path = "data/"

# %%
# dataset = np.array([PNG.ND_perlin_matrix([resolution, resolution], octaves=octaves, noise_cutoff_list=[0.5, 0, 1]) for _ in range(dataset_size)])
# np.save(data_path+'{resolution}x{resolution}_{octaves}_{dataset_size}_dataset.npy'.format(resolution=resolution, octaves=octaves, dataset_size=dataset_size), dataset)

# %%
dataset = np.load(data_path+'{resolution}x{resolution}_{octaves}_{dataset_size}_dataset.npy'.format(resolution=resolution, octaves=octaves, dataset_size=dataset_size))

# %%
from sklearn.preprocessing import MinMaxScaler

def perlin_M_to_dict(dimension_resolution, octaves, perlin_matrix):
    
    # Convert list to numpy array if needed
    array = np.array(perlin_matrix)
    shape = array.shape
 
    # Generate all possible coordinates in the N-dimensional array
    coordinates = np.indices(shape).reshape(len(shape), -1).T
    data = []      
    # Iterate over the coordinates and get the corresponding values
    for coord in coordinates:
        value = array[tuple(coord)]
        data.append(list(coord) + [value])
    
    # Separate the features and the value column
    features = [d[:-1] for d in data]
    values = [d[-1] for d in data]
    
    # Normalize the feature columns
    scaler = MinMaxScaler()
    normalized_features = scaler.fit_transform(features)
    
    # Create the output dictionary
    perlin_dict = {
        'features': normalized_features.tolist(),
        'values': values,
        'resolution': dimension_resolution,
        'coordinates': [f'x{i}' for i in range(len(shape))],
        'octaves': octaves,
        'dimension': len(dimension_resolution),
    }
    
    return perlin_dict

# %%
dict_dataset = [perlin_M_to_dict([resolution, resolution], octaves, m) for m in dataset]

# %%
X = [None for _ in range(len(drop_percs))]
for i, drop_perc in enumerate(drop_percs):
    X[i] = np.array([random_sampler(d, int(resolution*resolution*(1-drop_perc))) for d in dict_dataset])

# %% [markdown]
# Use knn to fill.

# %%
X_filled = np.zeros((len(drop_percs), dataset_size, resolution, resolution))
for i, drop_perc in enumerate(drop_percs):
    for j in range(dataset_size):
        dict = kNN_data_filler(X[i][j], rounding_threshold=0.9)
        for k in range(resolution*resolution):
            coords = np.round(dict['features']*(resolution-1))[k].astype(int)
            X_filled[i][j][coords[0]][coords[1]] = dict['values'][k]

# %% [markdown]
# Use gradient edge detection to generate edges.

# %%
y = np.array([ED_sim.gradient_edge_detection(dataset[i]) for i in range(dataset_size)]).astype(int)

# %% [markdown]
# ## Train test split

# %%
from sklearn.model_selection import train_test_split

# %%
indices_train = [0 for _ in range(len(drop_percs))]
indices_test = [0 for _ in range(len(drop_percs))]

# %%
seed = 3834
for i in range(len(drop_percs)):
    indices_train[i], indices_test[i] = train_test_split(range(dataset_size), random_state=seed+i)

# %% [markdown]
# ## CNN

# %%
from tensorflow import keras
from keras import models
from keras import layers
from sklearn.metrics import mean_squared_error

# %%
model_path = "checkpoints/"
if not os.path.exists(model_path):
    os.makedirs(model_path)

# %%
def weighted_cross_entropy(y_true, y_pred):
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(tf.equal(y_pred, 0), tf.ones_like(y_pred)*1e-7, y_pred)
    y_pred = tf.where(tf.equal(y_pred, 1), tf.ones_like(y_pred)*(1-1e-7), y_pred)

    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    a = tf.reduce_sum(y_true_f)/y_true_f.shape[0]
    b = 1 - a
    return -a*tf.experimental.numpy.inner(1-y_true_f, tf.math.log(1-y_pred_f))-b*tf.experimental.numpy.inner(y_true_f, tf.math.log(y_pred_f))

# %%
epochs = 100
batch_size = 32

history = [None for _ in range(len(drop_percs))]
pred_continuous = [None for _ in range(len(drop_percs))]
threshold = 0.5
pred_discrete = [None for _ in range(len(drop_percs))]
wces = np.zeros(len(drop_percs))
mses = np.zeros(len(drop_percs))

for i, drop_perc in enumerate(drop_percs):
    model = models.Sequential([
        layers.InputLayer((resolution,resolution,1,)),
        layers.Conv2D(32, (3,3), activation='relu', padding = 'same'),
        layers.Conv2D(64, (3,3), activation='relu', padding='same'),
        layers.MaxPooling2D((2,2)),
        layers.Conv2DTranspose(32, (3,3), strides=2, activation='relu', padding='same'),
        layers.Conv2DTranspose(1, (3,3), activation='sigmoid', padding='same')
    ])
    model.compile(optimizer='adam',
                    # loss='mse',
                    loss=weighted_cross_entropy,
                    # loss='categorical_crossentropy',
                    metrics=['mse'])

    X_train = X_filled[i][indices_train[i]]
    y_train = y[indices_train[i]]
    X_test = X_filled[i][indices_test[i]]
    y_test = y[indices_test[i]]

    X_train_tensor = tf.convert_to_tensor(X_train)
    y_train_tensor = tf.convert_to_tensor(y_train)
    X_test_tensor = tf.convert_to_tensor(X_test)
    y_test_tensor = tf.convert_to_tensor(y_test)

    history[i] = model.fit(X_train_tensor, y_train_tensor, validation_data=(X_test_tensor, y_test_tensor),
                      epochs=epochs, 
                      batch_size=batch_size)

    model.save(model_path+"knn_filling_cnn_{resolution}x{resolution}_{octaves}_{dataset_size}_{drop_perc}_{epochs}.keras".format(resolution=resolution, octaves=octaves, dataset_size=dataset_size, drop_perc=drop_perc, epochs=epochs))

    pred_continuous[i] = model.predict(X_test_tensor)

    pred_discrete[i] = np.array([a>threshold for a in pred_continuous[i]]).reshape(y_test.shape).astype(int)

    mses[i] = np.mean([mean_squared_error(y_test[j], pred_discrete[i][j]) for j in range(len(y_test))])
    wces[i] = np.mean([weighted_cross_entropy(y_test[j], pred_discrete[i][j]) for j in range(len(y_test))])
# Out:
# Epoch 1/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6799.2510 - mse: 0.2273 - val_loss: 6808.0791 - val_mse: 0.2289
# Epoch 8/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6789.3291 - mse: 0.2263 - val_loss: 6803.4692 - val_mse: 0.2266
# Epoch 9/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6784.7822 - mse: 0.2257 - val_loss: 6804.1885 - val_mse: 0.2240
# Epoch 10/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6774.1626 - mse: 0.2242 - val_loss: 6796.7144 - val_mse: 0.2269
# Epoch 11/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6767.1899 - mse: 0.2247 - val_loss: 6793.0537 - val_mse: 0.2258
# Epoch 12/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6770.1411 - mse: 0.2253 - val_loss: 6802.6445 - val_mse: 0.2331
# Epoch 13/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6779.0317 - mse: 0.2262 - val_loss: 6787.2881 - val_mse: 0.2246
# Epoch 14/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6763.0679 - mse: 0.2248 - val_loss: 6788.2378 - val_mse: 0.2264
# Epoch 15/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6765.9956 - mse: 0.2250 - val_loss: 6784.5020 - val_mse: 0.2290
# Epoch 16/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6778.6104 - mse: 0.2250 - val_loss: 6783.5391 - val_mse: 0.2217
# Epoch 17/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6746.2812 - mse: 0.2235 - val_loss: 6784.6533 - val_mse: 0.2222
# Epoch 18/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6760.1323 - mse: 0.2240 - val_loss: 6781.9365 - val_mse: 0.2262
# Epoch 19/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6783.0474 - mse: 0.2244 - val_loss: 6779.3184 - val_mse: 0.2215
# Epoch 20/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6750.2666 - mse: 0.2235 - val_loss: 6779.3154 - val_mse: 0.2258
# Epoch 21/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6768.2134 - mse: 0.2239 - val_loss: 6779.8789 - val_mse: 0.2237
# Epoch 22/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6745.4819 - mse: 0.2234 - val_loss: 6779.1919 - val_mse: 0.2278
# Epoch 23/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6744.0767 - mse: 0.2237 - val_loss: 6776.7627 - val_mse: 0.2276
# Epoch 24/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6749.3418 - mse: 0.2240 - val_loss: 6777.2441 - val_mse: 0.2235
# Epoch 25/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6718.5732 - mse: 0.2224 - val_loss: 6778.3145 - val_mse: 0.2197
# Epoch 26/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6764.7251 - mse: 0.2228 - val_loss: 6778.0278 - val_mse: 0.2264
# Epoch 27/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6725.0327 - mse: 0.2226 - val_loss: 6775.9893 - val_mse: 0.2266
# Epoch 28/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6745.0815 - mse: 0.2235 - val_loss: 6776.9761 - val_mse: 0.2242
# Epoch 29/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6704.6392 - mse: 0.2229 - val_loss: 6778.7192 - val_mse: 0.2229
# Epoch 30/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6727.3203 - mse: 0.2224 - val_loss: 6778.4644 - val_mse: 0.2225
# Epoch 31/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6731.5581 - mse: 0.2225 - val_loss: 6781.7441 - val_mse: 0.2294
# Epoch 32/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6723.5566 - mse: 0.2234 - val_loss: 6782.3467 - val_mse: 0.2181
# Epoch 33/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6739.9980 - mse: 0.2217 - val_loss: 6780.0947 - val_mse: 0.2208
# Epoch 34/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6710.6475 - mse: 0.2222 - val_loss: 6778.8428 - val_mse: 0.2217
# Epoch 35/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6712.8838 - mse: 0.2220 - val_loss: 6778.8174 - val_mse: 0.2249
# Epoch 36/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6714.6118 - mse: 0.2225 - val_loss: 6779.1318 - val_mse: 0.2275
# Epoch 37/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 6693.0967 - mse: 0.2223 - val_loss: 6780.5698 - val_mse: 0.2274
# Epoch 38/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6693.6348 - mse: 0.2232 - val_loss: 6782.6206 - val_mse: 0.2194
# Epoch 39/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6723.7734 - mse: 0.2221 - val_loss: 6776.0708 - val_mse: 0.2253
# Epoch 40/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6713.6914 - mse: 0.2222 - val_loss: 6780.3242 - val_mse: 0.2218
# Epoch 41/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6687.6357 - mse: 0.2216 - val_loss: 6778.5986 - val_mse: 0.2266
# Epoch 42/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6693.0483 - mse: 0.2219 - val_loss: 6786.2852 - val_mse: 0.2176
# Epoch 43/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6689.3823 - mse: 0.2210 - val_loss: 6781.1782 - val_mse: 0.2228
# Epoch 44/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6708.0977 - mse: 0.2212 - val_loss: 6781.5034 - val_mse: 0.2233
# Epoch 45/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6687.2783 - mse: 0.2219 - val_loss: 6785.4224 - val_mse: 0.2206
# Epoch 46/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6687.6147 - mse: 0.2216 - val_loss: 6783.7148 - val_mse: 0.2214
# Epoch 47/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6673.8169 - mse: 0.2208 - val_loss: 6785.9087 - val_mse: 0.2240
# Epoch 48/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6706.0176 - mse: 0.2215 - val_loss: 6784.3882 - val_mse: 0.2262
# Epoch 49/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6690.2637 - mse: 0.2218 - val_loss: 6783.8638 - val_mse: 0.2276
# Epoch 50/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6697.3921 - mse: 0.2227 - val_loss: 6784.5718 - val_mse: 0.2222
# Epoch 51/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6682.7729 - mse: 0.2210 - val_loss: 6784.6143 - val_mse: 0.2227
# Epoch 52/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6675.3359 - mse: 0.2211 - val_loss: 6788.9053 - val_mse: 0.2279
# Epoch 53/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6679.1338 - mse: 0.2212 - val_loss: 6788.2661 - val_mse: 0.2288
# Epoch 54/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6694.0054 - mse: 0.2219 - val_loss: 6789.3716 - val_mse: 0.2243
# Epoch 55/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6663.2725 - mse: 0.2205 - val_loss: 6792.4111 - val_mse: 0.2208
# Epoch 56/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6666.0322 - mse: 0.2197 - val_loss: 6791.4473 - val_mse: 0.2245
# Epoch 57/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6685.7759 - mse: 0.2215 - val_loss: 6796.1997 - val_mse: 0.2206
# Epoch 58/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6676.2192 - mse: 0.2202 - val_loss: 6797.3032 - val_mse: 0.2294
# Epoch 59/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6651.9380 - mse: 0.2204 - val_loss: 6805.3638 - val_mse: 0.2164
# Epoch 60/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6676.8657 - mse: 0.2199 - val_loss: 6793.4189 - val_mse: 0.2269
# Epoch 61/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6669.1396 - mse: 0.2204 - val_loss: 6797.0723 - val_mse: 0.2240
# Epoch 62/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6661.1577 - mse: 0.2201 - val_loss: 6795.6738 - val_mse: 0.2254
# Epoch 63/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6662.9365 - mse: 0.2207 - val_loss: 6803.4814 - val_mse: 0.2207
# Epoch 64/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6638.3267 - mse: 0.2194 - val_loss: 6803.5322 - val_mse: 0.2314
# Epoch 65/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6681.8115 - mse: 0.2212 - val_loss: 6803.8501 - val_mse: 0.2287
# Epoch 66/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6654.6177 - mse: 0.2199 - val_loss: 6806.0791 - val_mse: 0.2205
# Epoch 67/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6662.5562 - mse: 0.2192 - val_loss: 6802.0947 - val_mse: 0.2254
# Epoch 68/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6659.2300 - mse: 0.2208 - val_loss: 6797.4692 - val_mse: 0.2261
# Epoch 69/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6658.8125 - mse: 0.2207 - val_loss: 6806.7861 - val_mse: 0.2221
# Epoch 70/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6654.8320 - mse: 0.2194 - val_loss: 6811.5493 - val_mse: 0.2329
# Epoch 71/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6628.8950 - mse: 0.2204 - val_loss: 6809.6934 - val_mse: 0.2188
# Epoch 72/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6652.3896 - mse: 0.2190 - val_loss: 6811.0352 - val_mse: 0.2296
# Epoch 73/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6667.3057 - mse: 0.2198 - val_loss: 6814.7168 - val_mse: 0.2180
# Epoch 74/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6626.0576 - mse: 0.2181 - val_loss: 6810.4238 - val_mse: 0.2284
# Epoch 75/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6654.5459 - mse: 0.2199 - val_loss: 6812.4521 - val_mse: 0.2260
# Epoch 76/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6669.3892 - mse: 0.2200 - val_loss: 6810.1401 - val_mse: 0.2253
# Epoch 77/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6631.6406 - mse: 0.2191 - val_loss: 6814.2246 - val_mse: 0.2217
# Epoch 78/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6661.2646 - mse: 0.2191 - val_loss: 6815.0557 - val_mse: 0.2297
# Epoch 79/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6639.4766 - mse: 0.2198 - val_loss: 6823.3945 - val_mse: 0.2343
# Epoch 80/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6636.8516 - mse: 0.2205 - val_loss: 6817.3027 - val_mse: 0.2212
# Epoch 81/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6618.3252 - mse: 0.2188 - val_loss: 6823.3604 - val_mse: 0.2249
# Epoch 82/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6657.1567 - mse: 0.2191 - val_loss: 6821.7852 - val_mse: 0.2215
# Epoch 83/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6635.7339 - mse: 0.2191 - val_loss: 6824.1509 - val_mse: 0.2300
# Epoch 84/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6607.7241 - mse: 0.2191 - val_loss: 6823.8018 - val_mse: 0.2234
# Epoch 85/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6618.6577 - mse: 0.2192 - val_loss: 6823.1016 - val_mse: 0.2299
# Epoch 86/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6616.8262 - mse: 0.2190 - val_loss: 6822.7305 - val_mse: 0.2283
# Epoch 87/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6643.7070 - mse: 0.2193 - val_loss: 6833.7891 - val_mse: 0.2193
# Epoch 88/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6628.1162 - mse: 0.2184 - val_loss: 6827.8682 - val_mse: 0.2227
# Epoch 89/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6613.8540 - mse: 0.2183 - val_loss: 6831.6235 - val_mse: 0.2278
# Epoch 90/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6621.4771 - mse: 0.2190 - val_loss: 6833.1689 - val_mse: 0.2205
# Epoch 91/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6618.7627 - mse: 0.2175 - val_loss: 6827.8013 - val_mse: 0.2259
# Epoch 92/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6612.7549 - mse: 0.2185 - val_loss: 6837.4346 - val_mse: 0.2235
# Epoch 93/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6619.6069 - mse: 0.2173 - val_loss: 6831.8877 - val_mse: 0.2330
# Epoch 94/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6613.9785 - mse: 0.2195 - val_loss: 6839.7427 - val_mse: 0.2240
# Epoch 95/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6605.2793 - mse: 0.2177 - val_loss: 6848.6523 - val_mse: 0.2327
# Epoch 96/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6618.5708 - mse: 0.2180 - val_loss: 6832.2871 - val_mse: 0.2226
# Epoch 97/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6597.0112 - mse: 0.2183 - val_loss: 6835.7930 - val_mse: 0.2232
# Epoch 98/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6611.5283 - mse: 0.2179 - val_loss: 6840.2563 - val_mse: 0.2345
# Epoch 99/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6609.4233 - mse: 0.2186 - val_loss: 6840.3999 - val_mse: 0.2228
# Epoch 100/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6591.4761 - mse: 0.2163 - val_loss: 6837.5913 - val_mse: 0.2267
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
np.save(data_path+'knn_filling_cnn_{resolution}x{resolution}_{octaves}_{dataset_size}_{epochs}_pred.npy'.format(resolution=resolution, octaves=octaves, dataset_size=dataset_size, epochs=epochs), pred_continuous)

np.save(data_path+'knn_filling_cnn_{resolution}x{resolution}_{octaves}_{dataset_size}_{epochs}_mses.npy'.format(resolution=resolution, octaves=octaves, dataset_size=dataset_size, epochs=epochs), mses)

np.save(data_path+'knn_filling_cnn_{resolution}x{resolution}_{octaves}_{dataset_size}_{epochs}_wces.npy'.format(resolution=resolution, octaves=octaves, dataset_size=dataset_size, epochs=epochs), wces)

# %%
import matplotlib.pyplot as plt

plt.plot(drop_percs, wces, marker='o')
plt.xlabel("drop percentage")
plt.ylabel("weighted cross-entropy")
plt.show()

plt.plot(drop_percs, mses, marker='o')
plt.xlabel("drop percentage")
plt.ylabel("mse")
plt.show()

# %% [markdown]
# ## Some visualization

# %%
d = 0.5 # drop ratio
n = 239
cmap = 'gray_r'

# %%
import matplotlib.pyplot as plt

m = drop_percs.index(d)
k = indices_test[drop_percs.index(d)][n]

plt.imshow(dataset[k], cmap=cmap)
plt.title("original image")
plt.show()
plt.imshow(X_filled[m][n], cmap=cmap)
plt.title("{drop_perc}% dropped image filled by knn".format(drop_perc = drop_percs[m]*100))
plt.show()
plt.imshow(y[indices_test[m]][n], cmap=cmap)
plt.title("original edge")
plt.show()
plt.imshow(pred_discrete[m][n], cmap=cmap)
plt.title("predicted edge")
plt.show()

# %%
PNG.plot_perlin_2D_3D(perlin_M_to_dict([resolution, resolution], octaves, dataset[k]), cmap=cmap, edgecolors='black')
PNG.plot_perlin_2D_3D(np.array(X)[m][indices_test[m]][n], cmap=cmap, edgecolors='black')
PNG.plot_perlin_2D_3D(perlin_M_to_dict([resolution, resolution], octaves, X_filled[m][n]), cmap=cmap, edgecolors='black')
PNG.plot_perlin_2D_3D(perlin_M_to_dict([resolution, resolution], octaves, y[indices_test[m]][n]), cmap=cmap, edgecolors='black')
PNG.plot_perlin_2D_3D(perlin_M_to_dict([resolution, resolution], octaves, pred_discrete[m][n]), cmap=cmap, edgecolors='black')
