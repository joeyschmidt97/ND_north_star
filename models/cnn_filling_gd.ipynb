# %%
import os
import sys
module_path = os.path.abspath(os.path.join('../../..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import numpy as np
import tensorflow as tf

import ND_north_star.src.noise_generators.perlin_noise_generator as PNG # type: ignore
import ND_north_star.src.edge_detection.gradient_detection as ED_sim # type: ignore

# %%
tf.config.list_physical_devices('GPU')
# Out:
# []

# %% [markdown]
# Disable GPU

# %%
tf.config.set_visible_devices([], 'GPU')

# %% [markdown]
# ## Generate dataset

# %%
resolution = 30
octaves = 4
dataset_size = 1024
drop_percs = [x/100 for x in range(0, 100, 5)]

# %%
data_path = "data/"
if not os.path.exists(data_path):
    os.makedirs(data_path)
data_path = "data/"

# %%
# dataset = np.array([PNG.ND_perlin_matrix([resolution, resolution], octaves=octaves, noise_cutoff_list=[0.5, 0, 1]) for _ in range(dataset_size)])
# np.save(data_path+'{resolution}x{resolution}_{octaves}_{dataset_size}_dataset.npy'.format(resolution=resolution, octaves=octaves, dataset_size=dataset_size), dataset)

# %%
dataset = np.load(data_path+'{resolution}x{resolution}_{octaves}_{dataset_size}_dataset.npy'.format(resolution=resolution, octaves=octaves, dataset_size=dataset_size))

# %% [markdown]
# Drop data points with respect to each `drop_perc` in `drop_percs`. Then fill the dropped areas by

# %%
seed = 3834
X = np.zeros((len(drop_percs), dataset_size, resolution, resolution))
for i, drop_perc in enumerate(drop_percs):
    X[i] = dataset.copy()
    if drop_perc == 0:
        pass
    else:
        for j in range(dataset_size):
            np.random.seed(seed + j)
            drop_indices = np.random.choice(resolution * resolution, int(resolution * resolution * drop_perc), replace=False)
            x_coords = drop_indices // resolution
            y_coords = drop_indices % resolution
            for k in range(int(resolution * resolution * drop_perc)):
                X[i][j][x_coords[k]][y_coords[k]] = 0

# %%
y = dataset.copy()

# %%
edge = np.array([ED_sim.gradient_edge_detection(dataset[i]) for i in range(dataset_size)]).astype(int)

# %% [markdown]
# ## Train test split

# %%
from sklearn.model_selection import train_test_split

# %%
indices_train = [0 for _ in range(len(drop_percs))]
indices_test = [0 for _ in range(len(drop_percs))]

# %%
for i in range(len(drop_percs)):
    indices_train[i], indices_test[i] = train_test_split(range(dataset_size), random_state=seed+i)

# %% [markdown]
# ## CNN

# %%
from tensorflow import keras
from keras import models
from keras import layers
from sklearn.metrics import mean_squared_error

# %%
def weighted_cross_entropy(y_true, y_pred):
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(tf.equal(y_pred, 0), tf.ones_like(y_pred)*1e-7, y_pred)
    y_pred = tf.where(tf.equal(y_pred, 1), tf.ones_like(y_pred)*(1-1e-7), y_pred)

    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    a = tf.reduce_sum(y_true_f)/y_true_f.shape[0]
    b = 1 - a
    return -a*tf.experimental.numpy.inner(1-y_true_f, tf.math.log(1-y_pred_f))-b*tf.experimental.numpy.inner(y_true_f, tf.math.log(y_pred_f))

# %%
model_path = "checkpoints/"
if not os.path.exists(model_path):
    os.makedirs(model_path)

# %%
epochs = 100
batch_size = 32

history = [None for _ in range(len(drop_percs))]
fillings_continuous = [None for _ in range(len(drop_percs))]
fillings_discrete = [None for _ in range(len(drop_percs))]
preds = [None for _ in range(len(drop_percs))]
wces = np.zeros(len(drop_percs))
mses = np.zeros(len(drop_percs))

for i, drop_perc in enumerate(drop_percs):
    model = models.Sequential([
        layers.InputLayer((resolution,resolution,1,)),
        layers.Conv2D(32, (3,3), activation='relu', padding = 'same'),
        layers.Conv2D(64, (3,3), activation='relu', padding='same'),
        layers.MaxPooling2D((2,2)),
        layers.Conv2DTranspose(32, (3,3), strides=2, activation='relu', padding='same'),
        layers.Conv2DTranspose(1, (3,3), activation='sigmoid', padding='same')
    ])
    model.compile(optimizer='adam',
                    loss='mse',
                    # loss='categorical_crossentropy',
                    metrics=['mse'])

    X_train = X[i][indices_train[i]]
    y_train = y[indices_train[i]]
    X_test = X[i][indices_test[i]]
    y_test = y[indices_test[i]]

    X_train_tensor = tf.convert_to_tensor(X_train)
    y_train_tensor = tf.convert_to_tensor(y_train)
    X_test_tensor = tf.convert_to_tensor(X_test)
    y_test_tensor = tf.convert_to_tensor(y_test)

    history[i] = model.fit(X_train_tensor, y_train_tensor, validation_data=(X_test_tensor, y_test_tensor),
                      epochs=epochs, 
                      batch_size=batch_size)
    
    model.save(model_path+"filling_{resolution}x{resolution}_{octaves}_{dataset_size}_{drop_perc}_{epochs}.keras".format(resolution=resolution, octaves=octaves, dataset_size=dataset_size, drop_perc=drop_perc, epochs=epochs))

    fillings_continuous[i] = model.predict(X_test_tensor)

    fillings_discrete[i] = np.array(fillings_continuous[i]>0.5).reshape(np.array(y_test).shape).astype(int)

    preds[i] = np.array([ED_sim.gradient_edge_detection(fillings_discrete[i][j]) for j in range(len(y_test))]).reshape(np.array(y_test).shape).astype(int)

    wces[i] = np.mean([weighted_cross_entropy(edge[indices_test[i]][j], preds[i][j]) for j in range(len(y_test))])

    mses[i] = np.mean([mean_squared_error(edge[indices_test[i]][j], preds[i][j]) for j in range(len(y_test))])
# Out:
# Epoch 1/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2158 - mse: 0.2158 - val_loss: 0.0684 - val_mse: 0.0684
# Epoch 2/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0439 - mse: 0.0439 - val_loss: 0.0195 - val_mse: 0.0195
# Epoch 3/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0173 - mse: 0.0173 - val_loss: 0.0128 - val_mse: 0.0128
# Epoch 4/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 5/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 6/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 7/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 8/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 9/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 10/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 11/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 12/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 13/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 14/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 15/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.9480e-04 - mse: 9.9480e-04 - val_loss: 9.7556e-04 - val_mse: 9.7556e-04
# Epoch 16/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 8.5240e-04 - mse: 8.5240e-04 - val_loss: 8.6059e-04 - val_mse: 8.6059e-04
# Epoch 17/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.8901e-04 - mse: 7.8901e-04 - val_loss: 7.6216e-04 - val_mse: 7.6216e-04
# Epoch 18/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.6953e-04 - mse: 6.6953e-04 - val_loss: 6.9228e-04 - val_mse: 6.9228e-04
# Epoch 19/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.0764e-04 - mse: 6.0764e-04 - val_loss: 6.1721e-04 - val_mse: 6.1721e-04
# Epoch 20/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.2329e-04 - mse: 5.2329e-04 - val_loss: 5.6861e-04 - val_mse: 5.6861e-04
# Epoch 21/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.6819e-04 - mse: 4.6819e-04 - val_loss: 5.1896e-04 - val_mse: 5.1896e-04
# Epoch 22/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.3142e-04 - mse: 4.3142e-04 - val_loss: 4.7846e-04 - val_mse: 4.7846e-04
# Epoch 23/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.8548e-04 - mse: 3.8548e-04 - val_loss: 4.4312e-04 - val_mse: 4.4312e-04
# Epoch 24/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.7324e-04 - mse: 3.7324e-04 - val_loss: 4.0428e-04 - val_mse: 4.0428e-04
# Epoch 25/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.2426e-04 - mse: 3.2426e-04 - val_loss: 3.8436e-04 - val_mse: 3.8436e-04
# Epoch 26/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.9856e-04 - mse: 2.9856e-04 - val_loss: 3.5801e-04 - val_mse: 3.5801e-04
# Epoch 27/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.9109e-04 - mse: 2.9109e-04 - val_loss: 3.2927e-04 - val_mse: 3.2927e-04
# Epoch 28/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.6255e-04 - mse: 2.6255e-04 - val_loss: 3.1404e-04 - val_mse: 3.1404e-04
# Epoch 29/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.4615e-04 - mse: 2.4615e-04 - val_loss: 2.9149e-04 - val_mse: 2.9149e-04
# Epoch 30/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0841e-04 - mse: 2.0841e-04 - val_loss: 2.7624e-04 - val_mse: 2.7624e-04
# Epoch 31/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0444e-04 - mse: 2.0444e-04 - val_loss: 2.6220e-04 - val_mse: 2.6220e-04
# Epoch 32/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.7864e-04 - mse: 1.7864e-04 - val_loss: 2.5247e-04 - val_mse: 2.5247e-04
# Epoch 33/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.7092e-04 - mse: 1.7092e-04 - val_loss: 2.4192e-04 - val_mse: 2.4192e-04
# Epoch 34/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.6679e-04 - mse: 1.6679e-04 - val_loss: 2.2853e-04 - val_mse: 2.2853e-04
# Epoch 35/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 94/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 95/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 96/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 97/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 98/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 99/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 100/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0057 - val_mse: 0.0057
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 1/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2202 - mse: 0.2202 - val_loss: 0.0960 - val_mse: 0.0960
# Epoch 2/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0642 - mse: 0.0642 - val_loss: 0.0296 - val_mse: 0.0296
# Epoch 3/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0267 - mse: 0.0267 - val_loss: 0.0219 - val_mse: 0.0219
# Epoch 4/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0204 - mse: 0.0204 - val_loss: 0.0183 - val_mse: 0.0183
# Epoch 5/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0175 - mse: 0.0175 - val_loss: 0.0160 - val_mse: 0.0160
# Epoch 6/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0142 - val_mse: 0.0142
# Epoch 7/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0138 - mse: 0.0138 - val_loss: 0.0131 - val_mse: 0.0131
# Epoch 8/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0124 - val_mse: 0.0124
# Epoch 9/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 10/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 11/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 12/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 13/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 14/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 15/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 16/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 17/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 18/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 19/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 20/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 21/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 22/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 82/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 83/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0096 - val_mse: 0.0096
# Epoch 84/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0097 - val_mse: 0.0097
# Epoch 85/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 86/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 87/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 88/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 89/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 90/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 91/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 92/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0096 - val_mse: 0.0096
# Epoch 93/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 94/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 95/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 96/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 97/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 98/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 99/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 100/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0095 - val_mse: 0.0095
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 1/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.2233 - mse: 0.2233 - val_loss: 0.1188 - val_mse: 0.1188
# Epoch 2/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0817 - mse: 0.0817 - val_loss: 0.0347 - val_mse: 0.0347
# Epoch 3/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0317 - mse: 0.0317 - val_loss: 0.0266 - val_mse: 0.0266
# Epoch 4/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0256 - mse: 0.0256 - val_loss: 0.0231 - val_mse: 0.0231
# Epoch 5/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0225 - mse: 0.0225 - val_loss: 0.0207 - val_mse: 0.0207
# Epoch 6/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0202 - mse: 0.0202 - val_loss: 0.0190 - val_mse: 0.0190
# Epoch 7/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0189 - mse: 0.0189 - val_loss: 0.0178 - val_mse: 0.0178
# Epoch 8/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0176 - mse: 0.0176 - val_loss: 0.0170 - val_mse: 0.0170
# Epoch 9/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0170 - mse: 0.0170 - val_loss: 0.0164 - val_mse: 0.0164
# Epoch 10/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0138 - mse: 0.0138 - val_loss: 0.0141 - val_mse: 0.0141
# Epoch 40/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0141 - mse: 0.0141 - val_loss: 0.0141 - val_mse: 0.0141
# Epoch 41/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0138 - mse: 0.0138 - val_loss: 0.0142 - val_mse: 0.0142
# Epoch 42/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0139 - mse: 0.0139 - val_loss: 0.0141 - val_mse: 0.0141
# Epoch 43/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0139 - mse: 0.0139 - val_loss: 0.0142 - val_mse: 0.0142
# Epoch 44/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0138 - mse: 0.0138 - val_loss: 0.0140 - val_mse: 0.0140
# Epoch 45/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0140 - val_mse: 0.0140
# Epoch 46/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0140 - val_mse: 0.0140
# Epoch 47/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0139 - val_mse: 0.0139
# Epoch 48/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0140 - val_mse: 0.0140
# Epoch 49/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0140 - val_mse: 0.0140
# Epoch 50/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0139 - val_mse: 0.0139
# Epoch 51/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0139 - val_mse: 0.0139
# Epoch 52/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0139 - val_mse: 0.0139
# Epoch 53/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0139 - val_mse: 0.0139
# Epoch 54/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0139 - val_mse: 0.0139
# Epoch 55/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 56/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 57/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 58/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 59/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 60/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 61/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0130 - mse: 0.0130 - val_loss: 0.0138 - val_mse: 0.0138
# Epoch 62/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 63/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 64/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 65/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0136 - val_mse: 0.0136
# Epoch 66/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0138 - val_mse: 0.0138
# Epoch 67/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0136 - val_mse: 0.0136
# Epoch 68/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 69/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0136 - val_mse: 0.0136
# Epoch 70/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0130 - mse: 0.0130 - val_loss: 0.0136 - val_mse: 0.0136
# Epoch 71/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0138 - val_mse: 0.0138
# Epoch 72/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0130 - mse: 0.0130 - val_loss: 0.0136 - val_mse: 0.0136
# Epoch 73/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0138 - val_mse: 0.0138
# Epoch 74/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0130 - mse: 0.0130 - val_loss: 0.0136 - val_mse: 0.0136
# Epoch 75/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0136 - val_mse: 0.0136
# Epoch 76/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0136 - val_mse: 0.0136
# Epoch 77/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 78/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0127 - mse: 0.0127 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 79/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0136 - val_mse: 0.0136
# Epoch 80/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 81/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 82/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0127 - mse: 0.0127 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 83/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0136 - val_mse: 0.0136
# Epoch 84/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0136 - val_mse: 0.0136
# Epoch 85/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 86/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 87/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0127 - mse: 0.0127 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 88/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0136 - val_mse: 0.0136
# Epoch 89/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0127 - mse: 0.0127 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 90/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0136 - val_mse: 0.0136
# Epoch 91/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 92/100
# ...
# Epoch 68/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1576 - mse: 0.1576 - val_loss: 0.1582 - val_mse: 0.1582
# Epoch 69/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1584 - mse: 0.1584 - val_loss: 0.1583 - val_mse: 0.1583
# Epoch 70/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1583 - mse: 0.1583 - val_loss: 0.1591 - val_mse: 0.1591
# Epoch 71/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1578 - mse: 0.1578 - val_loss: 0.1584 - val_mse: 0.1584
# Epoch 72/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1575 - mse: 0.1575 - val_loss: 0.1582 - val_mse: 0.1582
# Epoch 73/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1583 - mse: 0.1583 - val_loss: 0.1582 - val_mse: 0.1582
# Epoch 74/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1581 - mse: 0.1581 - val_loss: 0.1586 - val_mse: 0.1586
# Epoch 75/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1574 - mse: 0.1574 - val_loss: 0.1583 - val_mse: 0.1583
# Epoch 76/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1572 - mse: 0.1572 - val_loss: 0.1584 - val_mse: 0.1584
# Epoch 77/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1569 - mse: 0.1569 - val_loss: 0.1584 - val_mse: 0.1584
# Epoch 78/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1579 - mse: 0.1579 - val_loss: 0.1582 - val_mse: 0.1582
# Epoch 79/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1576 - mse: 0.1576 - val_loss: 0.1588 - val_mse: 0.1588
# Epoch 80/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1577 - mse: 0.1577 - val_loss: 0.1585 - val_mse: 0.1585
# Epoch 81/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1566 - mse: 0.1566 - val_loss: 0.1586 - val_mse: 0.1586
# Epoch 82/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1567 - mse: 0.1567 - val_loss: 0.1584 - val_mse: 0.1584
# Epoch 83/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1576 - mse: 0.1576 - val_loss: 0.1583 - val_mse: 0.1583
# Epoch 84/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1569 - mse: 0.1569 - val_loss: 0.1584 - val_mse: 0.1584
# Epoch 85/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1572 - mse: 0.1572 - val_loss: 0.1593 - val_mse: 0.1593
# Epoch 86/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1575 - mse: 0.1575 - val_loss: 0.1596 - val_mse: 0.1596
# Epoch 87/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1576 - mse: 0.1576 - val_loss: 0.1584 - val_mse: 0.1584
# Epoch 88/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1568 - mse: 0.1568 - val_loss: 0.1583 - val_mse: 0.1583
# Epoch 89/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1575 - mse: 0.1575 - val_loss: 0.1586 - val_mse: 0.1586
# Epoch 90/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1566 - mse: 0.1566 - val_loss: 0.1591 - val_mse: 0.1591
# Epoch 91/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1578 - mse: 0.1578 - val_loss: 0.1583 - val_mse: 0.1583
# Epoch 92/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1564 - mse: 0.1564 - val_loss: 0.1590 - val_mse: 0.1590
# Epoch 93/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1573 - mse: 0.1573 - val_loss: 0.1584 - val_mse: 0.1584
# Epoch 94/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1578 - mse: 0.1578 - val_loss: 0.1585 - val_mse: 0.1585
# Epoch 95/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1570 - mse: 0.1570 - val_loss: 0.1586 - val_mse: 0.1586
# Epoch 96/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1564 - mse: 0.1564 - val_loss: 0.1586 - val_mse: 0.1586
# Epoch 97/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1567 - mse: 0.1567 - val_loss: 0.1587 - val_mse: 0.1587
# Epoch 98/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1572 - mse: 0.1572 - val_loss: 0.1587 - val_mse: 0.1587
# Epoch 99/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1575 - mse: 0.1575 - val_loss: 0.1590 - val_mse: 0.1590
# Epoch 100/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1562 - mse: 0.1562 - val_loss: 0.1587 - val_mse: 0.1587
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 1/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2430 - mse: 0.2430 - val_loss: 0.2226 - val_mse: 0.2226
# Epoch 2/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2207 - mse: 0.2207 - val_loss: 0.2139 - val_mse: 0.2139
# Epoch 3/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2115 - mse: 0.2115 - val_loss: 0.2016 - val_mse: 0.2016
# Epoch 4/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2017 - mse: 0.2017 - val_loss: 0.1998 - val_mse: 0.1998
# Epoch 5/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2010 - mse: 0.2010 - val_loss: 0.1992 - val_mse: 0.1992
# Epoch 6/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2006 - mse: 0.2006 - val_loss: 0.1989 - val_mse: 0.1989
# Epoch 7/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2000 - mse: 0.2000 - val_loss: 0.1986 - val_mse: 0.1986
# Epoch 8/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1990 - mse: 0.1990 - val_loss: 0.1984 - val_mse: 0.1984
# Epoch 9/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1995 - mse: 0.1995 - val_loss: 0.1984 - val_mse: 0.1984
# Epoch 10/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1992 - mse: 0.1992 - val_loss: 0.1988 - val_mse: 0.1988
# Epoch 11/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1992 - mse: 0.1992 - val_loss: 0.1981 - val_mse: 0.1981
# Epoch 12/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2002 - mse: 0.2002 - val_loss: 0.1980 - val_mse: 0.1980
# Epoch 13/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1991 - mse: 0.1991 - val_loss: 0.1982 - val_mse: 0.1982
# Epoch 14/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1985 - mse: 0.1985 - val_loss: 0.1980 - val_mse: 0.1980
# Epoch 15/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1992 - mse: 0.1992 - val_loss: 0.1979 - val_mse: 0.1979
# Epoch 16/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1988 - mse: 0.1988 - val_loss: 0.1984 - val_mse: 0.1984
# Epoch 17/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1988 - mse: 0.1988 - val_loss: 0.1979 - val_mse: 0.1979
# Epoch 18/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1985 - mse: 0.1985 - val_loss: 0.1978 - val_mse: 0.1978
# Epoch 19/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1981 - mse: 0.1981 - val_loss: 0.1979 - val_mse: 0.1979
# Epoch 20/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1987 - mse: 0.1987 - val_loss: 0.1978 - val_mse: 0.1978
# Epoch 21/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1984 - mse: 0.1984 - val_loss: 0.1979 - val_mse: 0.1979
# Epoch 22/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1986 - mse: 0.1986 - val_loss: 0.1976 - val_mse: 0.1976
# Epoch 23/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1986 - mse: 0.1986 - val_loss: 0.1982 - val_mse: 0.1982
# Epoch 24/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1979 - mse: 0.1979 - val_loss: 0.1977 - val_mse: 0.1977
# Epoch 25/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1989 - mse: 0.1989 - val_loss: 0.1983 - val_mse: 0.1983
# Epoch 26/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1986 - mse: 0.1986 - val_loss: 0.1977 - val_mse: 0.1977
# Epoch 27/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1986 - mse: 0.1986 - val_loss: 0.1975 - val_mse: 0.1975
# Epoch 28/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1980 - mse: 0.1980 - val_loss: 0.1978 - val_mse: 0.1978
# Epoch 29/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1977 - mse: 0.1977 - val_loss: 0.1976 - val_mse: 0.1976
# Epoch 30/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1986 - mse: 0.1986 - val_loss: 0.1976 - val_mse: 0.1976
# Epoch 31/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1981 - mse: 0.1981 - val_loss: 0.1976 - val_mse: 0.1976
# Epoch 32/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1972 - mse: 0.1972 - val_loss: 0.1978 - val_mse: 0.1978
# Epoch 33/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1975 - mse: 0.1975 - val_loss: 0.1975 - val_mse: 0.1975
# Epoch 34/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1973 - mse: 0.1973 - val_loss: 0.1976 - val_mse: 0.1976
# Epoch 35/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1973 - mse: 0.1973 - val_loss: 0.1977 - val_mse: 0.1977
# Epoch 36/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1974 - mse: 0.1974 - val_loss: 0.1974 - val_mse: 0.1974
# Epoch 37/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1974 - mse: 0.1974 - val_loss: 0.1974 - val_mse: 0.1974
# Epoch 38/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1979 - mse: 0.1979 - val_loss: 0.1976 - val_mse: 0.1976
# Epoch 39/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1973 - mse: 0.1973 - val_loss: 0.1974 - val_mse: 0.1974
# Epoch 40/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1988 - mse: 0.1988 - val_loss: 0.1973 - val_mse: 0.1973
# Epoch 41/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1981 - mse: 0.1981 - val_loss: 0.1974 - val_mse: 0.1974
# Epoch 42/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1976 - mse: 0.1976 - val_loss: 0.1977 - val_mse: 0.1977
# Epoch 43/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1977 - mse: 0.1977 - val_loss: 0.1974 - val_mse: 0.1974
# Epoch 44/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1984 - mse: 0.1984 - val_loss: 0.1981 - val_mse: 0.1981
# Epoch 45/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1983 - mse: 0.1983 - val_loss: 0.1973 - val_mse: 0.1973
# Epoch 46/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1967 - mse: 0.1967 - val_loss: 0.1973 - val_mse: 0.1973
# Epoch 47/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1979 - mse: 0.1979 - val_loss: 0.1975 - val_mse: 0.1975
# Epoch 48/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1973 - mse: 0.1973 - val_loss: 0.1973 - val_mse: 0.1973
# Epoch 49/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1973 - mse: 0.1973 - val_loss: 0.1977 - val_mse: 0.1977
# Epoch 50/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1969 - mse: 0.1969 - val_loss: 0.1973 - val_mse: 0.1973
# Epoch 51/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1976 - mse: 0.1976 - val_loss: 0.1974 - val_mse: 0.1974
# Epoch 52/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1973 - mse: 0.1973 - val_loss: 0.1976 - val_mse: 0.1976
# Epoch 53/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1982 - mse: 0.1982 - val_loss: 0.1975 - val_mse: 0.1975
# Epoch 54/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1976 - mse: 0.1976 - val_loss: 0.1974 - val_mse: 0.1974
# Epoch 55/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1980 - mse: 0.1980 - val_loss: 0.1973 - val_mse: 0.1973
# Epoch 56/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1967 - mse: 0.1967 - val_loss: 0.1973 - val_mse: 0.1973
# Epoch 57/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1963 - mse: 0.1963 - val_loss: 0.1972 - val_mse: 0.1972
# Epoch 58/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1973 - mse: 0.1973 - val_loss: 0.1972 - val_mse: 0.1972
# Epoch 59/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1978 - mse: 0.1978 - val_loss: 0.1974 - val_mse: 0.1974
# Epoch 60/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1978 - mse: 0.1978 - val_loss: 0.1973 - val_mse: 0.1973
# Epoch 61/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1977 - mse: 0.1977 - val_loss: 0.1974 - val_mse: 0.1974
# Epoch 62/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1970 - mse: 0.1970 - val_loss: 0.1972 - val_mse: 0.1972
# Epoch 63/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1975 - mse: 0.1975 - val_loss: 0.1972 - val_mse: 0.1972
# Epoch 64/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1974 - mse: 0.1974 - val_loss: 0.1974 - val_mse: 0.1974
# Epoch 65/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1974 - mse: 0.1974 - val_loss: 0.1976 - val_mse: 0.1976
# Epoch 66/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1971 - mse: 0.1971 - val_loss: 0.1981 - val_mse: 0.1981
# Epoch 67/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1960 - mse: 0.1960 - val_loss: 0.1973 - val_mse: 0.1973
# Epoch 68/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1966 - mse: 0.1966 - val_loss: 0.1974 - val_mse: 0.1974
# Epoch 69/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1974 - mse: 0.1974 - val_loss: 0.1974 - val_mse: 0.1974
# Epoch 70/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1960 - mse: 0.1960 - val_loss: 0.1974 - val_mse: 0.1974
# Epoch 71/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1969 - mse: 0.1969 - val_loss: 0.1973 - val_mse: 0.1973
# Epoch 72/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1970 - mse: 0.1970 - val_loss: 0.1974 - val_mse: 0.1974
# Epoch 73/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1972 - mse: 0.1972 - val_loss: 0.1975 - val_mse: 0.1975
# Epoch 74/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1972 - mse: 0.1972 - val_loss: 0.1972 - val_mse: 0.1972
# Epoch 75/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1962 - mse: 0.1962 - val_loss: 0.1973 - val_mse: 0.1973
# Epoch 76/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1964 - mse: 0.1964 - val_loss: 0.1972 - val_mse: 0.1972
# Epoch 77/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1971 - mse: 0.1971 - val_loss: 0.1974 - val_mse: 0.1974
# Epoch 78/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1961 - mse: 0.1961 - val_loss: 0.1975 - val_mse: 0.1975
# Epoch 79/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1966 - mse: 0.1966 - val_loss: 0.1973 - val_mse: 0.1973
# Epoch 80/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1962 - mse: 0.1962 - val_loss: 0.1987 - val_mse: 0.1987
# Epoch 81/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1970 - mse: 0.1970 - val_loss: 0.1973 - val_mse: 0.1973
# Epoch 82/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1959 - mse: 0.1959 - val_loss: 0.1974 - val_mse: 0.1974
# Epoch 83/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1967 - mse: 0.1967 - val_loss: 0.1977 - val_mse: 0.1977
# Epoch 84/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1967 - mse: 0.1967 - val_loss: 0.1972 - val_mse: 0.1972
# Epoch 85/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1968 - mse: 0.1968 - val_loss: 0.1972 - val_mse: 0.1972
# Epoch 86/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1963 - mse: 0.1963 - val_loss: 0.1974 - val_mse: 0.1974
# Epoch 87/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1966 - mse: 0.1966 - val_loss: 0.1974 - val_mse: 0.1974
# Epoch 88/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1979 - mse: 0.1979 - val_loss: 0.1974 - val_mse: 0.1974
# Epoch 89/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1964 - mse: 0.1964 - val_loss: 0.1973 - val_mse: 0.1973
# Epoch 90/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1964 - mse: 0.1964 - val_loss: 0.1973 - val_mse: 0.1973
# Epoch 91/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1964 - mse: 0.1964 - val_loss: 0.1973 - val_mse: 0.1973
# Epoch 92/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1973 - mse: 0.1973 - val_loss: 0.1974 - val_mse: 0.1974
# Epoch 93/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1974 - mse: 0.1974 - val_loss: 0.1975 - val_mse: 0.1975
# Epoch 94/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1970 - mse: 0.1970 - val_loss: 0.1974 - val_mse: 0.1974
# Epoch 95/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1976 - mse: 0.1976 - val_loss: 0.1976 - val_mse: 0.1976
# Epoch 96/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1961 - mse: 0.1961 - val_loss: 0.1977 - val_mse: 0.1977
# Epoch 97/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1967 - mse: 0.1967 - val_loss: 0.1974 - val_mse: 0.1974
# Epoch 98/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1966 - mse: 0.1966 - val_loss: 0.1973 - val_mse: 0.1973
# Epoch 99/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1962 - mse: 0.1962 - val_loss: 0.1979 - val_mse: 0.1979
# Epoch 100/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1974 - mse: 0.1974 - val_loss: 0.1973 - val_mse: 0.1973
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
np.save(data_path+'cnn_filling_gd_{resolution}x{resolution}_{octaves}_{dataset_size}_{epochs}_pred.npy'.format(resolution=resolution, octaves=octaves, dataset_size=dataset_size, epochs=epochs), fillings_continuous)

np.save(data_path+'cnn_filling_gd_{resolution}x{resolution}_{octaves}_{dataset_size}_{epochs}_wces.npy'.format(resolution=resolution, octaves=octaves, dataset_size=dataset_size, epochs=epochs), wces)

np.save(data_path+'cnn_filling_gd_{resolution}x{resolution}_{octaves}_{dataset_size}_{epochs}_mses.npy'.format(resolution=resolution, octaves=octaves, dataset_size=dataset_size, epochs=epochs), mses)

# %% [markdown]
# Training curves

# %%
import matplotlib.pyplot as plt

for i, drop_perc in enumerate(drop_percs):
    plt.figure(figsize = (8,6))
    plt.scatter(range(1, epochs + 1),history[i].history['loss'], label = "Training Loss")
    plt.scatter(range(1, epochs + 1),history[i].history['val_loss'], label = "Validation Loss")

    plt.title("drop percentage = {drop_perc}%".format(drop_perc=drop_perc*100))
    plt.xlabel("Epoch", fontsize=12)
    plt.ylabel("Loss Function Value", fontsize=12)

    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)

    plt.legend(fontsize=12)

    plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(drop_percs, wces, marker='o')
plt.xlabel("drop percentage")
plt.ylabel("weighted cross-entropy")
plt.show()

plt.plot(drop_percs, mses, marker='o')
plt.xlabel("drop percentage")
plt.ylabel("mse")
plt.show()

# %% [markdown]
# ## Some visualization

# %%
d = 0.5 # drop ratio
n = 6
cmap = 'gray_r'

# %%
m = drop_percs.index(d)
k = indices_test[drop_percs.index(d)][n]

plt.imshow(dataset[k], cmap=cmap)
plt.title("original image")
plt.show()
plt.imshow(X[m][indices_test[m]][n], cmap=cmap)
plt.title("{drop_perc}% dropped image filled with 0".format(drop_perc = drop_percs[m]*100))
plt.show()
plt.imshow(edge[indices_test[m]][n], cmap=cmap)
plt.title("original edge")
plt.show()
plt.imshow(fillings_continuous[m][n], cmap=cmap)
plt.title("filled image (continuous)")
plt.show()
plt.imshow(fillings_discrete[m][n], cmap=cmap)
plt.title("filled image (discrete)")
plt.show()
plt.imshow(preds[m][n], cmap=cmap)
plt.title("predicted edge")
plt.show()
