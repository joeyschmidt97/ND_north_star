# %%
import os
os.getcwd()
os.chdir('..')
os.getcwd()
from src.perlin_noise_generator import generate_binary_perlin_noise, plot_2d, plot_3d

# %%
import os
os.chdir('/global/u1/j/joeschm/tools/ND_north_star')
os.getcwd()
# Out:
# '/global/u1/j/joeschm/tools/ND_north_star'

# %%
pic_2d = generate_binary_perlin_noise([100,100], 4)

print(type(pic_2d))

plot_2d(pic_2d)
# Out:
# <class 'list'>

# %%
pic_3d = generate_binary_perlin_noise([10,10,10], 4)

x = 0

plot_3d(pic_3d)
