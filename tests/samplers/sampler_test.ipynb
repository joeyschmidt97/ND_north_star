# %%
import ND_north_star.src.noise_generators.perlin_noise_generator as PNG
from ND_north_star.src.utils.sample_function import sample_coords_and_values

# %%
resolution = 60
dimensions = [resolution, resolution]

dataset = PNG.normalized_perlin_coord_values(dimensions, 4)
PNG.plot_perlin_2D_3D(dataset, 'black')

sampled_dataset = sample_coords_and_values(dataset, 500)
PNG.plot_perlin_2D_3D(sampled_dataset, 'black')

sampled_dataset = sample_coords_and_values(dataset, 500, method='lhs')
PNG.plot_perlin_2D_3D(sampled_dataset, 'black')
