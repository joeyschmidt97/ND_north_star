# %%
import ND_north_star.src.noise_generators.perlin_noise_generator as PNG

import ND_north_star.src.edge_detection.complex as ED_com
import ND_north_star.src.edge_detection.gradient_detection as ED_sim

# %%
resolution = 30
dimensions = [resolution, resolution]

perlin_noise = PNG.ND_perlin_noise_generator(dimensions, 4, [0,1], [0.5, 0, 1])

coord_array, values = PNG.perlin_M_to_coords(perlin_noise)

# Plot perlin noise coord in x and y coordinates and with intensity values surrounded by a black outline
PNG.plot_perlin_2D_3D(coord_array, values, 'black')

# %%
import numpy as np
import matplotlib.pyplot as plt


# Detect edges
edges = ED_sim.gradient_edge_detection(perlin_noise)

# edges = ED_com.scipy_edge_detection(perlin_noise)


# Assuming `data` is your original data array and `edges` is the binary edge detection result
# First, ensure `edges` is in an appropriate format for contour plotting
# You might need to compute an array that matches the dimensions of `data`
# For demonstration, let's assume `edges` directly represents the detected edges as a binary array

# Plotting
fig, ax = plt.subplots(figsize=(6, 6))

# Original data
ax.imshow(perlin_noise, cmap='gray')
ax.set_title('Data with Detected Edges')

# Detected edges overlay
# We use np.argwhere to find indices of edge pixels and overlay them on the original plot
ys, xs = np.nonzero(edges)  # Get the x, y coordinates of edge points
ax.scatter(xs, ys, color='red', s=1)  # Plot them as red points; adjust size as needed

# ax.axis('off')  # Hide axis for better visualization

plt.show()
